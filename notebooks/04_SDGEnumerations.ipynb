# %% [markdown]
# # Explore SDG Enumerations
#
#
# For all SDG statistical variables currently in DC, we have the list of ‘constraintProperties’, i.e., the list of dimensions that are actively used by at least one statistical variable.  Each of these properties has a set of values, which in turn as of a specific Enumeration class.

# %%
# Import Data Commons

import pandas as pd
import numpy as np
import datacommons_pandas as dc

# Import other required libraries
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd

import json
import time

import ast

import os
from dotenv import load_dotenv

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import clear_output, display
from IPython.core.display import HTML, JSON

import requests
from bs4 import BeautifulSoup


import sys
sys.path.append('../') # add the project's root directory to the system path

from utils_excel import * # import the utils_excel module from the project's root directory

# %% [markdown]
# ---

# %%
load_dotenv()
api_key = os.getenv("DC_KEY")
# Out:
# True

# %% [markdown]
# ### SPARQL Query

# %%
# set up the API endpoint URL
url = "https://api.datacommons.org/v1/query"
headers = {"X-API-Key": api_key}

# %% [markdown]
# ### REST API

# %%
def call_api(endpoint, parameters):
    url = f"http://api.datacommons.org/{endpoint}{parameters}?key={api_key}"
    print(f"http://api.datacommons.org/{endpoint}{parameters}")
    response = requests.get(url)
    return json.loads(response.content)

# %% [markdown]
# ---

# %%
variable_properties = pd.read_excel('../data/output/Variable_Properties.xlsx').fillna('')
variable_properties.head(3)
# Out:
#                dcid measuredProperty measuredProperty__name
# 0  sdg/VC_DSR_AFFCT            value                  value  \
# 1   sdg/VC_DSR_DAFF            value                  value
# 2  sdg/VC_DSR_IJILN            value                  value
#
#                                             memberOf
# 0  ['dc/g/SDG_1.5.1', 'dc/g/SDG_11.5.1', 'dc/g/SD...  \
# 1  ['dc/g/SDG_1.5.1', 'dc/g/SDG_11.5.1', 'dc/g/SD...
# 2  ['dc/g/SDG_1.5.1', 'dc/g/SDG_11.5.1', 'dc/g/SD...
#
#                                       memberOf__name
# 0  ['1.5.1: Number of deaths, missing persons and...  \
# 1  ['1.5.1: Number of deaths, missing persons and...
# 2  ['1.5.1: Number of deaths, missing persons and...
#
#                                                 name    populationType
# 0              Number of people affected by disaster  SDG_VC_DSR_AFFCT  \
# 1  Number of directly affected persons attributed...   SDG_VC_DSR_DAFF
# 2  Number of injured or ill people attributed to ...  SDG_VC_DSR_IJILN
#
#                                 populationType__name
# 0              Number of people affected by disaster  \
# 1  Number of directly affected persons attributed...
# 2  Number of injured or ill people attributed to ...
#
#                       provenance       provenance__name  ...
# 0  dc/base/HumanReadableStatVars  HumanReadableStatVars  ...  \
# 1  dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
# 2  dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
#
#   sdg_typeOfWasteTreatment sdg_typeOfWasteTreatment__name
# 0                                                          \
# 1
# 2
#
#   sdg_frequencyOfChlorophyllAConcentration
# 0                                           \
# 1
# 2
#
#   sdg_frequencyOfChlorophyllAConcentration__name sdg_deviationLevel
# 0                                                                    \
# 1
# 2
#
#   sdg_deviationLevel__name sdg_typeOfRenewableTechnology
# 0                                                         \
# 1
# 2
#
#   sdg_typeOfRenewableTechnology__name sdg_foodWasteSector
# 0                                                          \
# 1
# 2
#
#   sdg_foodWasteSector__name
# 0
# 1
# 2
#
# [3 rows x 88 columns]

# %% [markdown]
# ### 1. Obtain properties directly linked to SDG statistical variables through the `onstraintProperties` relation

# %%
ConstraintProperties = list(variable_properties['constraintProperties'])


ConstraintProperties_unique = []

for element in ConstraintProperties:
    # Check if the element is a simple string
    if isinstance(element, str) and not element.startswith("["):
        if element not in ConstraintProperties_unique:
            ConstraintProperties_unique.append(element)
    # Check if the element is a complex string that can be parsed as an array of simple strings
    elif isinstance(element, str) and element.startswith("[") and element.endswith("]"):
        parsed_array = ast.literal_eval(element)
        for value in parsed_array:
            if value not in ConstraintProperties_unique:
                ConstraintProperties_unique.append(value)

ConstraintProperties_unique = sorted(ConstraintProperties_unique)
ConstraintProperties_unique.remove('')
print(f"{len(ConstraintProperties_unique)=}")
ConstraintProperties_unique
# Out:
# len(ConstraintProperties_unique)=36
# ['age',
#  'disabilityStatus',
#  'educationalAttainment',
#  'gender',
#  'sdg_activity',
#  'sdg_counterpart',
#  'sdg_customBreakdown',
#  'sdg_deviationLevel',
#  'sdg_fiscalInterventionStage',
#  'sdg_foodWasteSector',
#  'sdg_frequencyOfChlorophyllAConcentration',
#  'sdg_governmentName',
#  'sdg_groundsOfDiscrimination',
#  'sdg_ihrCapacity',
#  'sdg_levelOfGovernment',
#  'sdg_levelStatus',
#  'sdg_location',
#  'sdg_migratoryStatus',
#  'sdg_modeOfTransportation',
#  'sdg_mountainElevation',
#  'sdg_nameOfInternationalInstitution',
#  'sdg_nameOfNonCommunicableDisease',
#  'sdg_parliamentaryCommittees',
#  'sdg_policyDomains',
#  'sdg_policyInstruments',
#  'sdg_populationGroup',
#  'sdg_quantile',
#  'sdg_samplingStations',
#  'sdg_serviceAttribute',
#  'sdg_substanceUseDisorders',
#  'sdg_typeOfOccupation',
#  'sdg_typeOfProduct',
#  'sdg_typeOfRenewableTechnology',
#  'sdg_typeOfSkill',
#  'sdg_typeOfSpeed',
#  'sdg_typeOfWasteTreatment']

# %%
enumerations = []

for idx, dimension in enumerate(ConstraintProperties_unique):

    dim_values = sorted(list(set([x for x in list(variable_properties[dimension]) if x != ''])))
    
    for dv in dim_values:
        row = dict()
        row['dimension'] = dimension
        row['dim_value'] = dv
        x = call_api('v1/property/values', f'/out/{dv}/typeOf')['values']
        row['dim_enumeration'] =  x[0]['dcid']
        row['dim_enumeration_name'] =  x[0]['name']
        enumerations.append(row)
    
enumerations = pd.DataFrame(enumerations)
enumerations
# Out:
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_1-14/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_1-4/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_10-14/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_10-17/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_10GEQ/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_12-14/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_12-24/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_12GEQ/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_14GEQ/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_15-19/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_15-24/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_15-49/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_15-64/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_15GEQ/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_16-65/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_16GEQ/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_18-29/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_18-74/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_18GEQ/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_2-14/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_20-24/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_20-64/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_20-74/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_20GEQ/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_25-34/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_25-44/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_25GEQ/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_30-70/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_35-44/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum_45-54/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_AgeEnum
/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_SENIORMAN/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_TOTALPSP/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-0/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-1/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-2/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-3/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-4/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-5/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-6/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-7/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-8/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-9/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco08-X/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-0/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-1/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-2/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-3/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-4/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-5/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-6/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-7/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-8/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-9/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfOccupationEnum_isco88-X/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_AGR/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_ARM/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_BIM/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_CLO/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_COL/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_CPR/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_CRO/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_FEO/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_FOF/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_GAS/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_GBO/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_IND/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_MAZ/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_MEO/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_MIL/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_NFO/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_NMA/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_NMC/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_NMM/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_OIL/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_ONT/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_PET/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_RIC/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_SOR/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_TEX/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_WCH/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_WHE/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfProductEnum_WOD/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfRenewableTechnologyEnum_BIOENERGY/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfRenewableTechnologyEnum_GEOTHERMAL/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfRenewableTechnologyEnum_HYDROPOWER/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfRenewableTechnologyEnum_MARINE/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfRenewableTechnologyEnum_MULTIPLE/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfRenewableTechnologyEnum_SOLAR/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfRenewableTechnologyEnum_WIND/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_ARSP/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_CMFL/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_COPA/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_EMAIL/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_EPRS/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_INST/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_LITE/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_NUME/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_PCPR/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_PRVCY/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_SCRTY/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_SKILLMATH/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_SKILLREAD/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_SOFT/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_TRAF/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSkillEnum_VRFY/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSpeedEnum_10MBPS/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSpeedEnum_256KT2MBPS/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfSpeedEnum_2MT10MBPS/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfWasteTreatmentEnum_COMPOST/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfWasteTreatmentEnum_INCINRT/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfWasteTreatmentEnum_INCINRTEGY/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfWasteTreatmentEnum_LANDFIL/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfWasteTreatmentEnum_LANDFILCTL/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfWasteTreatmentEnum_OTHERWM/typeOf
# http://api.datacommons.org/v1/property/values/out/SDG_TypeOfWasteTreatmentEnum_RECYCL/typeOf
#                     dimension                                dim_value
# 0                         age                         SDG_AgeEnum_1-14  \
# 1                         age                          SDG_AgeEnum_1-4
# 2                         age                        SDG_AgeEnum_10-14
# 3                         age                        SDG_AgeEnum_10-17
# 4                         age                        SDG_AgeEnum_10GEQ
# ..                        ...                                      ...
# 979  sdg_typeOfWasteTreatment  SDG_TypeOfWasteTreatmentEnum_INCINRTEGY
# 980  sdg_typeOfWasteTreatment     SDG_TypeOfWasteTreatmentEnum_LANDFIL
# 981  sdg_typeOfWasteTreatment  SDG_TypeOfWasteTreatmentEnum_LANDFILCTL
# 982  sdg_typeOfWasteTreatment     SDG_TypeOfWasteTreatmentEnum_OTHERWM
# 983  sdg_typeOfWasteTreatment      SDG_TypeOfWasteTreatmentEnum_RECYCL
#
#                   dim_enumeration      dim_enumeration_name
# 0                     SDG_AgeEnum                   AgeEnum
# 1                     SDG_AgeEnum                   AgeEnum
# 2                     SDG_AgeEnum                   AgeEnum
# 3                     SDG_AgeEnum                   AgeEnum
# 4                     SDG_AgeEnum                   AgeEnum
# ..                            ...                       ...
# 979  SDG_TypeOfWasteTreatmentEnum  TypeOfWasteTreatmentEnum
# 980  SDG_TypeOfWasteTreatmentEnum  TypeOfWasteTreatmentEnum
# 981  SDG_TypeOfWasteTreatmentEnum  TypeOfWasteTreatmentEnum
# 982  SDG_TypeOfWasteTreatmentEnum  TypeOfWasteTreatmentEnum
# 983  SDG_TypeOfWasteTreatmentEnum  TypeOfWasteTreatmentEnum
#
# [984 rows x 4 columns]

# %%
Dimension_Enumeration = enumerations[['dimension', 'dim_enumeration', 'dim_enumeration_name']].drop_duplicates()

new_col_names = {'dimension': 'dimension', 'dim_enumeration': 'enumeration', 'dim_enumeration_name': 'enumeration_name'}
Dimension_Enumeration = Dimension_Enumeration.rename(columns=new_col_names)
Dimension_Enumeration = Dimension_Enumeration.reset_index(drop=True)
Dimension_Enumeration

write_to_excel(Dimension_Enumeration, '../data/output/Dimension_Enumeration.xlsx', 'Dimension_Enumeration', 90)
# Out:
#                                    dimension
# 0                                        age  \
# 1                           disabilityStatus
# 2                      educationalAttainment
# 3                                     gender
# 4                               sdg_activity
# 5                            sdg_counterpart
# 6                        sdg_customBreakdown
# 7                         sdg_deviationLevel
# 8                sdg_fiscalInterventionStage
# 9                        sdg_foodWasteSector
# 10  sdg_frequencyOfChlorophyllAConcentration
# 11                        sdg_governmentName
# 12               sdg_groundsOfDiscrimination
# 13                           sdg_ihrCapacity
# 14                     sdg_levelOfGovernment
# 15                           sdg_levelStatus
# 16                              sdg_location
# 17                       sdg_migratoryStatus
# 18                  sdg_modeOfTransportation
# 19                     sdg_mountainElevation
# 20        sdg_nameOfInternationalInstitution
# 21          sdg_nameOfNonCommunicableDisease
# 22               sdg_parliamentaryCommittees
# 23                         sdg_policyDomains
# 24                     sdg_policyInstruments
# 25                       sdg_populationGroup
# 26                              sdg_quantile
# 27                      sdg_samplingStations
# 28                      sdg_serviceAttribute
# 29                 sdg_substanceUseDisorders
# 30                      sdg_typeOfOccupation
# 31                         sdg_typeOfProduct
# 32             sdg_typeOfRenewableTechnology
# 33                           sdg_typeOfSkill
# 34                           sdg_typeOfSpeed
# 35                  sdg_typeOfWasteTreatment
#
#                                      enumeration
# 0                                    SDG_AgeEnum  \
# 1                       SDG_DisabilityStatusEnum
# 2                         SDG_EducationLevelEnum
# 3                                    SDG_SexEnum
# 4                               SDG_ActivityEnum
# 5                            SDG_CounterpartEnum
# 6                        SDG_CustomBreakdownEnum
# 7                         SDG_DeviationLevelEnum
# 8                SDG_FiscalInterventionStageEnum
# 9                        SDG_FoodWasteSectorEnum
# 10  SDG_FrequencyOfChlorophyllAConcentrationEnum
# 11                        SDG_GovernmentNameEnum
# 12               SDG_GroundsOfDiscriminationEnum
# 13                           SDG_IhrCapacityEnum
# 14                     SDG_LevelOfGovernmentEnum
# 15                           SDG_LevelStatusEnum
# 16                              SDG_LocationEnum
# 17                       SDG_MigratoryStatusEnum
# 18                  SDG_ModeOfTransportationEnum
# 19                     SDG_MountainElevationEnum
# 20        SDG_NameOfInternationalInstitutionEnum
# 21          SDG_NameOfNonCommunicableDiseaseEnum
# 22               SDG_ParliamentaryCommitteesEnum
# 23                         SDG_PolicyDomainsEnum
# 24                     SDG_PolicyInstrumentsEnum
# 25                       SDG_PopulationGroupEnum
# 26                              SDG_QuantileEnum
# 27                      SDG_SamplingStationsEnum
# 28                      SDG_ServiceAttributeEnum
# 29                 SDG_SubstanceUseDisordersEnum
# 30                      SDG_TypeOfOccupationEnum
# 31                         SDG_TypeOfProductEnum
# 32             SDG_TypeOfRenewableTechnologyEnum
# 33                           SDG_TypeOfSkillEnum
# 34                           SDG_TypeOfSpeedEnum
# 35                  SDG_TypeOfWasteTreatmentEnum
#
#                             enumeration_name
# 0                                    AgeEnum
# 1                       DisabilityStatusEnum
# 2                         EducationLevelEnum
# 3                                    SexEnum
# 4                               ActivityEnum
# 5                            CounterpartEnum
# 6                        CustomBreakdownEnum
# 7                         DeviationLevelEnum
# 8                FiscalInterventionStageEnum
# 9                        FoodWasteSectorEnum
# 10  FrequencyOfChlorophyllAConcentrationEnum
# 11                        GovernmentNameEnum
# 12               GroundsOfDiscriminationEnum
# 13                           IhrCapacityEnum
# 14                     LevelOfGovernmentEnum
# 15                           LevelStatusEnum
# 16                              LocationEnum
# 17                       MigratoryStatusEnum
# 18                  ModeOfTransportationEnum
# 19                     MountainElevationEnum
# 20        NameOfInternationalInstitutionEnum
# 21          NameOfNonCommunicableDiseaseEnum
# 22               ParliamentaryCommitteesEnum
# 23                         PolicyDomainsEnum
# 24                     PolicyInstrumentsEnum
# 25                       PopulationGroupEnum
# 26                              QuantileEnum
# 27                      SamplingStationsEnum
# 28                      ServiceAttributeEnum
# 29                 SubstanceUseDisordersEnum
# 30                      TypeOfOccupationEnum
# 31                         TypeOfProductEnum
# 32             TypeOfRenewableTechnologyEnum
# 33                           TypeOfSkillEnum
# 34                           TypeOfSpeedEnum
# 35                  TypeOfWasteTreatmentEnum

# %%
for idx, e in enumerate(Dimension_Enumeration['enumeration']):
    code_list = call_api('v1/property/values', f'/in/{e}/typeOf')['values']
    write_to_excel(pd.DataFrame(code_list), f'../data/output/Enumerations/{e}.xlsx', 'Enumeration', 90)
# Out:
# http://api.datacommons.org/v1/property/values/in/SDG_AgeEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_DisabilityStatusEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_EducationLevelEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_SexEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_ActivityEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_CounterpartEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_CustomBreakdownEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_DeviationLevelEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_FiscalInterventionStageEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_FoodWasteSectorEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_FrequencyOfChlorophyllAConcentrationEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_GovernmentNameEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_GroundsOfDiscriminationEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_IhrCapacityEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_LevelOfGovernmentEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_LevelStatusEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_LocationEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_MigratoryStatusEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_ModeOfTransportationEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_MountainElevationEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_NameOfInternationalInstitutionEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_NameOfNonCommunicableDiseaseEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_ParliamentaryCommitteesEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_PolicyDomainsEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_PolicyInstrumentsEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_PopulationGroupEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_QuantileEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_SamplingStationsEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_ServiceAttributeEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_SubstanceUseDisordersEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_TypeOfOccupationEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_TypeOfProductEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_TypeOfRenewableTechnologyEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_TypeOfSkillEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_TypeOfSpeedEnum/typeOf
# http://api.datacommons.org/v1/property/values/in/SDG_TypeOfWasteTreatmentEnum/typeOf
