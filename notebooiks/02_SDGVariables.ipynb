# %% [markdown]
# # Load required libraries

# %%
# Import Data Commons

import pandas as pd
import numpy as np
import datacommons_pandas as dc

# Import other required libraries
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd

import json
import time

import os
from dotenv import load_dotenv

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import clear_output, display
from IPython.core.display import HTML, JSON

import requests
from bs4 import BeautifulSoup


import sys
sys.path.append('../') # add the project's root directory to the system path

from utils_excel import * # import the utils_excel module from the project's root directory

# %% [markdown]
# # Load key

# %%
load_dotenv()
api_key = os.getenv("DC_KEY")
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ### SPARQL Query

# %%
# set up the API endpoint URL
url = "https://api.datacommons.org/v1/query"
headers = {"X-API-Key": api_key}

# %% [markdown]
# ### REST API

# %%
def call_api(endpoint, parameters):
    url = f"http://api.datacommons.org/{endpoint}{parameters}?key={api_key}"
    print(f"http://api.datacommons.org/{endpoint}{parameters}?key={api_key}")
    response = requests.get(url)
    return json.loads(response.content)

# %% [markdown]
# ## 1. Get list of all `SDG_Series`

# %%
query = """
        SELECT DISTINCT ?dcid ?name  
        WHERE {
          # ?x typeOf SDG_Series .
          # ?x dcid ?dcid .
          # ?x name ?name .
        }
        ORDER BY DESC(?dcid)
        """
request_body = {"sparql": query}

# send the request to the API endpoint
response = requests.post(url, headers=headers, data=json.dumps(request_body))

results = json.loads(response.content)['rows']

df_SDG_SERIES = pd.DataFrame([('SDG_Series', r['cells'][0]['value'], r['cells'][1]['value'], f"https://datacommons.org/browser/{r['cells'][0]['value']}") for r in results], columns=['typeOf', 'dcid', 'name', 'DC Graph Browser URL'])
df_SDG_SERIES
# Out:
#          typeOf                dcid
# 0    SDG_Series     SDG_VC_VOV_SEXL  \
# 1    SDG_Series     SDG_VC_VOV_ROBB
# 2    SDG_Series     SDG_VC_VOV_PHYL
# 3    SDG_Series     SDG_VC_VOV_GDSD
# 4    SDG_Series     SDG_VC_VOH_SXPH
# ..          ...                 ...
# 983  SDG_Series  SDG_AG_FOOD_WST_PC
# 984  SDG_Series     SDG_AG_FOOD_WST
# 985  SDG_Series      SDG_AG_FLS_PCT
# 986  SDG_Series    SDG_AG_FLS_INDEX
# 987  SDG_Series      SDG_AG_FLS_IDX
#
#                                                   name
# 0    Proportion of population subjected to sexual v...  \
# 1    Proportion of population subjected to robbery ...
# 2    Proportion of population subjected to physical...
# 3    Proportion of population reporting having felt...
# 4    Proportion of persons victim of physical or se...
# ..                                                 ...
# 983                              Food waste per capita
# 984                                         Food waste
# 985                               Food loss percentage
# 986                             Global food loss index
# 987                               Food loss percentage
#
#                                   DC Graph Browser URL
# 0      https://datacommons.org/browser/SDG_VC_VOV_SEXL
# 1      https://datacommons.org/browser/SDG_VC_VOV_ROBB
# 2      https://datacommons.org/browser/SDG_VC_VOV_PHYL
# 3      https://datacommons.org/browser/SDG_VC_VOV_GDSD
# 4      https://datacommons.org/browser/SDG_VC_VOH_SXPH
# ..                                                 ...
# 983  https://datacommons.org/browser/SDG_AG_FOOD_WS...
# 984    https://datacommons.org/browser/SDG_AG_FOOD_WST
# 985     https://datacommons.org/browser/SDG_AG_FLS_PCT
# 986   https://datacommons.org/browser/SDG_AG_FLS_INDEX
# 987     https://datacommons.org/browser/SDG_AG_FLS_IDX
#
# [988 rows x 4 columns]

# %%
write_to_excel(df_SDG_SERIES, '../data/output/SDG_Series.xlsx', 'SDG_Series', 90)

# %% [markdown]
# ## 2. Find the statistical variables associated with each SDG_Series

# %%
statistical_variables = []
statistical_variables_log = []

endpoint = 'v1/property/values'

for index, sdg_series_id in df_SDG_SERIES['dcid'].items():
    
    clear_output(wait=True)
    
    parameters = f'/in/{sdg_series_id}/populationType'
    
    respons_data = call_api(endpoint, parameters)
    try:
        x = pd.DataFrame(respons_data['values'])
        x['SDG_Series'] = sdg_series_id
        statistical_variables.append(x)
        log_entry = {'SDG_Series': sdg_series_id, 'No_variables': len(x)}
    except:
        log_entry = {'SDG_Series': sdg_series_id, 'No_variables': 0}
    print(log_entry)
    statistical_variables_log.append(log_entry)
    clear_output(wait=True)
statistical_variables = pd.concat(statistical_variables)
statistical_variables_log =pd.DataFrame(statistical_variables_log)
# Out:
# http://api.datacommons.org/v1/property/values/in/SDG_AG_FLS_IDX/populationType?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
# {'SDG_Series': 'SDG_AG_FLS_IDX', 'No_variables': 0}

# %%
write_to_excel(statistical_variables, '../data/output/statistical_variables.xlsx', 'StatisticalVariables', 90)
write_to_excel(statistical_variables_log, '../data/output/statistical_variables_log.xlsx', 'StatisticalVariables', 90)

# %% [markdown]
# ## List the properties of each statistical variable

# %%
variable_properties = []

for i, v in statistical_variables['dcid'].items():

    # if v!= 'sdg/VC_VOV_GDSD_AGE_FEMALE':
    #     continue
        
    clear_output(wait=True)
    
    d = dict()
    d['dcid'] = v
    
    properties = call_api('v1/properties', f"/out/{v}")['properties']
    print('\n')
    for p in properties:
        property_values = call_api('v1/property/values', f'/out/{v}/{p}')['values']
        if p != 'name':
            if len(property_values)>1:
                d[p] = [item['dcid'] for item in property_values]
                d[f"{p}__name"] = [item['name'] for item in property_values]
            else:
                d[p] = property_values[0]['dcid'] 
                d[f"{p}__name"] = property_values[0]['name']
        else: 
            d[p] = property_values[0]['value'] 
            
    
    variable_properties.append(d)
    
variable_properties = pd.DataFrame(variable_properties).astype(str)
variable_properties = variable_properties.drop_duplicates()
variable_properties
# Out:
# http://api.datacommons.org/v1/properties/out/sdg/AG_FOOD_WST_RTL?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
#
#
# http://api.datacommons.org/v1/property/values/out/sdg/AG_FOOD_WST_RTL/constraintProperties?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
# http://api.datacommons.org/v1/property/values/out/sdg/AG_FOOD_WST_RTL/measuredProperty?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
# http://api.datacommons.org/v1/property/values/out/sdg/AG_FOOD_WST_RTL/memberOf?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
# http://api.datacommons.org/v1/property/values/out/sdg/AG_FOOD_WST_RTL/name?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
# http://api.datacommons.org/v1/property/values/out/sdg/AG_FOOD_WST_RTL/populationType?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
# http://api.datacommons.org/v1/property/values/out/sdg/AG_FOOD_WST_RTL/provenance?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
# http://api.datacommons.org/v1/property/values/out/sdg/AG_FOOD_WST_RTL/sdg_foodWasteSector?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
# http://api.datacommons.org/v1/property/values/out/sdg/AG_FOOD_WST_RTL/statType?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
# http://api.datacommons.org/v1/property/values/out/sdg/AG_FOOD_WST_RTL/typeOf?key=AIzaSyCkAGkNZanUeVo6GRTqvR4lTrRr895LguA
#                          dcid measuredProperty measuredProperty__name
# 0             sdg/VC_VOV_SEXL            value                  value  \
# 1      sdg/VC_VOV_SEXL_FEMALE            value                  value
# 2        sdg/VC_VOV_SEXL_MALE            value                  value
# 3             sdg/VC_VOV_ROBB            value                  value
# 4      sdg/VC_VOV_ROBB_FEMALE            value                  value
# ...                       ...              ...                    ...
# 3659  sdg/AG_FOOD_WST_PC_OOHC            value                  value
# 3660   sdg/AG_FOOD_WST_PC_RTL            value                  value
# 3661      sdg/AG_FOOD_WST_HHS            value                  value
# 3662     sdg/AG_FOOD_WST_OOHC            value                  value
# 3663      sdg/AG_FOOD_WST_RTL            value                  value
#
#                                     memberOf
# 0                          dc/g/SDGVCVOVSEXL  \
# 1                   dc/g/SDGVCVOVSEXL_gender
# 2                   dc/g/SDGVCVOVSEXL_gender
# 3                          dc/g/SDGVCVOVROBB
# 4                   dc/g/SDGVCVOVROBB_gender
# ...                                      ...
# 3659  dc/g/SDGAGFOODWSTPC_sdgfoodWasteSector
# 3660  dc/g/SDGAGFOODWSTPC_sdgfoodWasteSector
# 3661    dc/g/SDGAGFOODWST_sdgfoodWasteSector
# 3662    dc/g/SDGAGFOODWST_sdgfoodWasteSector
# 3663    dc/g/SDGAGFOODWST_sdgfoodWasteSector
#
#                                          memberOf__name
# 0     Proportion of Population Subjected To Sexual V...  \
# 1     Proportion of Population Subjected To Sexual V...
# 2     Proportion of Population Subjected To Sexual V...
# 3     Proportion of Population Subjected To Robbery ...
# 4     Proportion of Population Subjected To Robbery ...
# ...                                                 ...
# 3659         Food Waste Per Capita by Food Waste Sector
# 3660         Food Waste Per Capita by Food Waste Sector
# 3661                    Food Waste by Food Waste Sector
# 3662                    Food Waste by Food Waste Sector
# 3663                    Food Waste by Food Waste Sector
#
#                                                    name      populationType
# 0     Proportion of population subjected to sexual v...     SDG_VC_VOV_SEXL  \
# 1     Proportion of population subjected to sexual v...     SDG_VC_VOV_SEXL
# 2     Proportion of population subjected to sexual v...     SDG_VC_VOV_SEXL
# 3     Proportion of population subjected to robbery ...     SDG_VC_VOV_ROBB
# 4     Proportion of population subjected to robbery ...     SDG_VC_VOV_ROBB
# ...                                                 ...                 ...
# 3659     Food waste per capita: Out-of-home consumption  SDG_AG_FOOD_WST_PC
# 3660                      Food waste per capita: Retail  SDG_AG_FOOD_WST_PC
# 3661                             Food waste: Households     SDG_AG_FOOD_WST
# 3662                Food waste: Out-of-home consumption     SDG_AG_FOOD_WST
# 3663                                 Food waste: Retail     SDG_AG_FOOD_WST
#
#                                    populationType__name
# 0     Proportion of population subjected to sexual v...  \
# 1     Proportion of population subjected to sexual v...
# 2     Proportion of population subjected to sexual v...
# 3     Proportion of population subjected to robbery ...
# 4     Proportion of population subjected to robbery ...
# ...                                                 ...
# 3659                              Food waste per capita
# 3660                              Food waste per capita
# 3661                                         Food waste
# 3662                                         Food waste
# 3663                                         Food waste
#
#                          provenance       provenance__name  ...
# 0     dc/base/HumanReadableStatVars  HumanReadableStatVars  ...  \
# 1     dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
# 2     dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
# 3     dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
# 4     dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
# ...                             ...                    ...  ...
# 3659  dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
# 3660  dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
# 3661  dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
# 3662  dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
# 3663  dc/base/HumanReadableStatVars  HumanReadableStatVars  ...
#
#      sdg_typeOfWasteTreatment sdg_typeOfWasteTreatment__name
# 0                         nan                            nan  \
# 1                         nan                            nan
# 2                         nan                            nan
# 3                         nan                            nan
# 4                         nan                            nan
# ...                       ...                            ...
# 3659                      nan                            nan
# 3660                      nan                            nan
# 3661                      nan                            nan
# 3662                      nan                            nan
# 3663                      nan                            nan
#
#      sdg_frequencyOfChlorophyllAConcentration
# 0                                         nan  \
# 1                                         nan
# 2                                         nan
# 3                                         nan
# 4                                         nan
# ...                                       ...
# 3659                                      nan
# 3660                                      nan
# 3661                                      nan
# 3662                                      nan
# 3663                                      nan
#
#      sdg_frequencyOfChlorophyllAConcentration__name sdg_deviationLevel
# 0                                               nan                nan  \
# 1                                               nan                nan
# 2                                               nan                nan
# 3                                               nan                nan
# 4                                               nan                nan
# ...                                             ...                ...
# 3659                                            nan                nan
# 3660                                            nan                nan
# 3661                                            nan                nan
# 3662                                            nan                nan
# 3663                                            nan                nan
#
#      sdg_deviationLevel__name sdg_typeOfRenewableTechnology
# 0                         nan                           nan  \
# 1                         nan                           nan
# 2                         nan                           nan
# 3                         nan                           nan
# 4                         nan                           nan
# ...                       ...                           ...
# 3659                      nan                           nan
# 3660                      nan                           nan
# 3661                      nan                           nan
# 3662                      nan                           nan
# 3663                      nan                           nan
#
#      sdg_typeOfRenewableTechnology__name           sdg_foodWasteSector
# 0                                    nan                           nan  \
# 1                                    nan                           nan
# 2                                    nan                           nan
# 3                                    nan                           nan
# 4                                    nan                           nan
# ...                                  ...                           ...
# 3659                                 nan  SDG_FoodWasteSectorEnum_OOHC
# 3660                                 nan   SDG_FoodWasteSectorEnum_RTL
# 3661                                 nan   SDG_FoodWasteSectorEnum_HHS
# 3662                                 nan  SDG_FoodWasteSectorEnum_OOHC
# 3663                                 nan   SDG_FoodWasteSectorEnum_RTL
#
#      sdg_foodWasteSector__name
# 0                          nan
# 1                          nan
# 2                          nan
# 3                          nan
# 4                          nan
# ...                        ...
# 3659   Out-of-home consumption
# 3660                    Retail
# 3661                Households
# 3662   Out-of-home consumption
# 3663                    Retail
#
# [3634 rows x 88 columns]

# %%
write_to_excel(variable_properties, '../data/output/Variable_Properties.xlsx', 'Variable_Properties', 90)
